# %% [markdown]
# D'après [Wikipedia](https://fr.wikipedia.org/wiki/D%C3%A9veloppement_d%C3%A9cimal_p%C3%A9riodique#Longueur_de_la_p%C3%A9riode),
# la période de $1/d$, si $(10, d) = 1$ (ce que l'on peut supposer), est l'ordre de $10$
# dans le groupe des inversibles de $\mathbf Z/n\mathbf Z$.

# %%
# si (a,n) = (1), renvoie l'ordre de a dans le groupe des inversibles de Z/nZ
# peu efficace mais suffisant ici (mieux : utiliser sympy.n_order)
def order(a, n):
    p = a
    e = 1
    while (p - 1) % n:
        p = p * a
        e += 1
    return e

long = 0
for d in range(2, 1000):
    if d % 2 and d% 5:
        l = order(10, d)
        if l > long:
            long = l
            D = d
D
# Out:
# 983
