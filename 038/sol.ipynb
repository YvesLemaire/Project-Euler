# %%
Z = 0
x = 1
while x * 10 ** len(str(x)) <= 987654321: # x <= 10000
    x += 1
    n = 0
    y = 0
    digits = ''
    l = 0 # length(digits)
    ok = True
    while True:
        n += 1
        y += x # nx
        s = str(y)
        digits +=  s
        l += len(s)
        if len(set(digits)) == l and '0' not in s:
            if n != 1 and l == 9:
                z = int(digits)
                Z = max(Z, z)
        else:
            break 
Z
# Out:
# 932718654
