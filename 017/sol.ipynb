# %%
X = len("onetwothreefourfivesixseveneightnine")                                   #   1, .. ,  9
Y = len("teneleventwelvethirteenfourteenfifteensixteenseventeeneighteennineteen") #  10, .. , 19
Z = 10 * len("twentythirtyfortyfiftysixtyseventyeightyninety") + 8 * X            #  20, .. , 99
T = X + 9 * len("hundred") + 99 * (X + 9 * len("hundredand")) + 9 * (X + Y + Z)   # 100, .. ,999
X + Y + Z + T + len("onethousand")
# Out:
# 21124
