# %% [markdown]
# $$\left(\sum_{k=1}^nk\right)^2-\sum_{k=1}^nk^2=\left(\frac{n(n+1)}{2}\right)^2-\frac{n(n+1)(2n+1)}{6}=\frac{(n^3-n)(3n+2)}{12}$$

# %%
n = 100
(n ** 3 - n) * (3 * n + 2) // 12
# Out:
# 25164150
