# %%
with open('names.txt', 'r') as f:
    names = sorted(f.read().replace('"', '').split(',')) # liste ordonnee des prenoms
sum((n + 1) * sum(ord(c) - 64 for c in names[n]) for n in range(len(names)))
# Out:
# 871198282
